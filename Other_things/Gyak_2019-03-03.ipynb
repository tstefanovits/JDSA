# %%
import pandas as pd

# C:\Users\Nandi\Google Drive\_Data36\beolvas.sav

birdstrikes = pd.read_csv('birdstrikes.csv', sep=';', header=0, 
                         names=['type', 'airport', 'model', 'flightdate', 'ID', 'opeator', 'origin', 'collected', 'sky', 'cost'])

# %%
# dataviz import
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
birdstrikes.head(5)
# Out:
#        type                   airport      model flightdate      ID  \
# 0  Airplane  NEWARK LIBERTY INTL ARPT  B-757-200   01/01/00  200508
# 1  Airplane                   UNKNOWN  B-737-300   01/01/00  206593
# 2  Airplane       DENVER INTL AIRPORT  B-737-300   01/01/00  206594
# 3  Airplane  CHICAGO O'HARE INTL ARPT  B-727-200   01/01/00  204095
# 4       NaN       JOHN F KENNEDY INTL    UNKNOWN   01/01/00  202963
#
#                 opeator      origin  collected       sky  cost
# 0  CONTINENTAL AIRLINES  New Jersey      False  Overcast     0
# 1       UNITED AIRLINES         NaN      False       NaN     0
# 2       UNITED AIRLINES    Colorado      False       NaN     0
# 3       UNITED AIRLINES    Illinois      False       NaN     0
# 4               UNKNOWN    New York       True       NaN     0

# %%
train_aa = pd.read_csv('train_aa.csv', sep=',')

# %%
print ('max =', max(train_aa.SalePrice))
# Out:
# max = 755000

# %%
train_aa.SalePrice.values
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %%
import statistics as stat

# %%
# na, ez már jó
stat.mean([1,5]), stat.median([1,5])
# Out:
# (3.0, 3.0)

# %%
# stat: min, max, modus, stddev
print('mean=', round(stat.mean(train_aa.SalePrice)))
round(stat.median(train_aa.SalePrice)), stat.mode(train_aa.SalePrice), round(stat.stdev(train_aa.SalePrice))
# Out:
# mean= 180921
# (163000, 140000, 79443)

# %%
import random

# %%
random.random()
# Out:
# 0.5202224231075354

# %%
print ("Szia Bálint!")
# Out:
# Szia Bálint!

# %%
train_aa.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
# oszlopkijelölés
train_aa.Alley.head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Alley, dtype: object

# %%
train_aa[['Id', 'Alley']].head(5)
# Out:
#    Id Alley
# 0   1   NaN
# 1   2   NaN
# 2   3   NaN
# 3   4   NaN
# 4   5   NaN

# %%
# sorkijelölés, teljes adatbázisban végrehajtja a kijelölést
train_aa[train_aa.LotShape == 'Reg'].tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# sorkijelölés, csak bizonyos oszlopra, de a head-et nem jeleníti meg
train_aa[train_aa.LotShape == 'Reg'].Alley.tail(5)
# Out:
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# Name: Alley, dtype: object

# %%
# sorkijelölés, csak bizonyos oszlopOKra: ez még nem megy :(
train_aa[train_aa.LotShape == 'Reg'].tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# többes feltétel egyelőre nem megy
train_aa[train_aa.MSSubClass>20].head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 5         Lvl    AllPub    ...            0    NaN  MnPrv        Shed     700
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# esetszámokat megszámolja, minden változóra, vagy csak egyre (pl. Id)
train_aa[train_aa.MSSubClass>20].Id.count()
# Out:
# 924

# %%
# megszámolja az Id-t, szűrés nincs előtte - az üres oszlopokat nem számolja bele!
train_aa.Id.count()
# Out:
# 1460

# %%
# többes kijelölés mégis, sikerült!

train_aa[train_aa.MSSubClass>60][train_aa.LotShape=='Reg'].tail(8)
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1421  1422         120       RL         53.0     4043   Pave   NaN      Reg
# 1422  1423         120       RM         37.0     4435   Pave   NaN      Reg
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
# többes kijelölés, ez is tud esetet számolni 

print ("esetszám =", train_aa[train_aa.MSSubClass>60][train_aa.LotShape=='Reg'].MSSubClass.count())
# Out:
# esetszám = 290
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # groupby

# %%
# jön a groupby! 01
train_aa.groupby('LotShape').LotShape.count()
# Out:
# LotShape
# IR1    484
# IR2     41
# IR3     10
# Reg    925
# Name: LotShape, dtype: int64

# %%
# jön a groupby! 02: így egymás alá mennek
round(train_aa.groupby('LotShape').MSSubClass.mean(),1), train_aa.groupby('LotShape').MSSubClass.median()
# Out:
# (LotShape
#  IR1    50.1
#  IR2    52.1
#  IR3    41.0
#  Reg    60.8
#  Name: MSSubClass, dtype: float64, LotShape
#  IR1    60
#  IR2    60
#  IR3    45
#  Reg    50
#  Name: MSSubClass, dtype: int64)

# %%
# jön a groupby! 02: így egymás alá mennek, de így is
print (round(train_aa.groupby('LotShape').MSSubClass.mean(),1), train_aa.groupby('LotShape').MSSubClass.median())
# Out:
# LotShape
# IR1    50.1
# IR2    52.1
# IR3    41.0
# Reg    60.8
# Name: MSSubClass, dtype: float64 LotShape
# IR1    60
# IR2    60
# IR3    45
# Reg    50
# Name: MSSubClass, dtype: int64

# %%
# próba:
# round(train_aa.groupby('LotShape').stat.mean(train_aa.MSSubClass),1), train_aa.groupby('LotShape').MSSubClass.median()
stat.median(train_aa.MSSubClass)
# Out:
# 50.0

# %%
 #1: no, ez király!
print ("MSSubClass statisztikai ismérvei:")
train_aa.MSSubClass.describe()
# Out:
# MSSubClass statisztikai ismérvei:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
# groupby boolean
# train_aa.head(2)
round(train_aa.groupby('LotShape').SalePrice.mean(),1)
# Out:
# LotShape
# IR1    206101.7
# IR2    239833.4
# IR3    216036.5
# Reg    164754.8
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Vizual

# %%
train_aa.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
# 01: értelmetlen chart :)

train_aa.YrSold.plot()

# %%
# 02: na, ez már valami - YrSold alapján elemszám megoszlás (alapja: Id)

train_aa.groupby('YrSold').Id.count().plot(kind='bar')

# %%
# 03: sum SalePrice by Id, jó az ábra, de az e

train_aa.groupby('YrSold').SalePrice.sum().plot(kind='bar')
plt.xlabel("Years")
plt.ylabel("SalePrice")

# %%
train_aa.groupby('YrSold').SalePrice.sum()
# Out:
# YrSold
# 2006    57320530
# 2007    61214777
# 2008    53917695
# 2009    60648051
# 2010    31043893
# Name: SalePrice, dtype: int64

# %%
# alap-kiinduló

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x-tengely label')
plt.ylabel('y-tengely label')

plt.title("A chart címét ide")

plt.legend() # jelmagy megjelenít, amelybe a labelek kerülnek

plt.show()
